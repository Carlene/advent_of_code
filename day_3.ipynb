'.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '#', '#', '.'], ['.', '.', '.', '.', '#', '.', '.', '.', '#', '.', '.', '.', '#', '.', '#', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '#', '#', '.', '#', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '#', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '#', '.', '.', '#', '.', '.', '.', '.', '#', '.', '.', '.', '.', '#'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
# ...

# %%
def test(actual, expected):
    if actual == expected:
        print("Seems OK to me!")
    else:
        print(f"I expected {expected} but got {actual}")

# %%
new_map = [['.','#','.']
        ,['.','#','#']
        ,['#','#','#']
        ,['.','#','.']
        ,['#','#','.']
        ,['.','.','.']
        ,['#','#','#']
        ,['.','.','.']]

# %%
#this skips rows, has to go three across on every row

def slope_movement_3_1(toboggan_map):
    slope_horizontal = 3
    start = 0
    tree_count = 0

    for i, area in enumerate(toboggan_map[1:]):
        start = (start + slope_horizontal) % len(area)
        if area[start] == '#':
            tree_count += 1

    return tree_count

# %%
test(slope_movement_3_1(new_map), 3)

test(slope_movement_3_1([['.','#','.','#']
                    ,['.','#','#','#']
                    ,['#','#','#','#']
                    ,['.','#','.','#']
                    ,['#','#','.','#']
                    ,['.','.','.','#']
                    ,['.','#','#','#']
                    ,['#','.','.','#']]), 6)

test(slope_movement_3_1([['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']]), 7)
# Out:
# Seems OK to me!
# Seems OK to me!
# Seems OK to me!

# %%
slope_movement_3_1(toboggan_map)
# Out:
# 203

# %%
lst_count = 0

for lsts in toboggan_map:
    lst_count +=1

print(lst_count)
# Out:
# 323

# %%
def slope_movement_1_1(toboggan_map):
    slope_horizontal = 1
    start = 0
    tree_count = 0

    for i, area in enumerate(toboggan_map[1:]):
        start = (start + slope_horizontal) % len(area)
        if area[start] == '#':
            tree_count += 1

    return tree_count

# %%
def slope_movement_5_1(toboggan_map):
    slope_horizontal = 5
    start = 0
    tree_count = 0

    for i, area in enumerate(toboggan_map[1:]):
        start = (start + slope_horizontal) % len(area)
        if area[start] == '#':
            tree_count += 1

    return tree_count

# %%
def slope_movement_7_1(toboggan_map):
    slope_horizontal = 7
    start = 0
    tree_count = 0

    for i, area in enumerate(toboggan_map[1:]):
        start = (start + slope_horizontal) % len(area)
        if area[start] == '#':
            tree_count += 1

    return tree_count

# %%
def slope_movement_1_2(toboggan_map):
    slope_horizontal = 1
    start = 0
    tree_count = 0

    for i, area in enumerate(toboggan_map[1:]):
        if i % 2 != 0: 
            start = (start + slope_horizontal) % len(area)
            if area[start] == '#':
                tree_count += 1

    return tree_count

# %%
test(slope_movement_1_2(new_map), 2)

test(slope_movement_1_2([['.','#','.','#']
                    ,['.','#','#','#']
                    ,['#','#','#','#']
                    ,['.','#','.','#']
                    ,['#','#','.','#']
                    ,['.','.','.','#']
                    ,['.','#','#','#']
                    ,['#','.','.','#']]), 2)

test(slope_movement_1_2([['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']
                    ,['#','#','#','#','#','#','#','#', '#','#','#','#']]), 3)
# Out:
# Seems OK to me!
# Seems OK to me!
# Seems OK to me!

# %%
def multiply_trees(slope1, slope2, slope3, slope4, slope5):
    return (slope1* slope2* slope3* slope4* slope5)

# %%
multiply_trees(slope_movement_1_2(toboggan_map), slope_movement_7_1(toboggan_map), slope_movement_5_1(toboggan_map), 
               slope_movement_1_1(toboggan_map), slope_movement_3_1(toboggan_map))
# Out:
# 3316272960
